# %%
import pandas as pd
import numpy as np
#url = 'https://en.wikipedia.org/wiki/The_World%27s_Billionaires'
#df_list = pd.read_html(url)

# %%
len(df_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-611ee89a8259> in <module>
# ----> 1 len(df_list)
#
# NameError: name 'df_list' is not defined

# %%
df_list[2]
# Out:
#    No.                      Name Net worth (USD)  Age    Nationality  \
# 0    1                Jeff Bezos    $177 billion   57  United States
# 1    2                 Elon Musk    $151 billion   49  United States
# 2    3  Bernard Arnault & family    $150 billion   72         France
# 3    4                Bill Gates    $124 billion   65  United States
# 4    5           Mark Zuckerberg     $97 billion   36  United States
# 5    6            Warren Buffett     $96 billion   90  United States
# 6    7             Larry Ellison     $93 billion   76  United States
# 7    8                Larry Page   $91.5 billion   48  United States
# 8    9               Sergey Brin     $89 billion   47  United States
# 9   10             Mukesh Ambani   $84.5 billion   63          India
#
#    Source(s) of wealth
# 0               Amazon
# 1        Tesla, SpaceX
# 2                 LVMH
# 3            Microsoft
# 4             Facebook
# 5   Berkshire Hathaway
# 6   Oracle Corporation
# ...

# %% [markdown]
# ### Łączenie się ze stroną wikipedii i wczytanie jej jako pandas data frame.

# %%
url2 = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
df_toronto = pd.read_html(url2)

# %%
len(df_toronto)
# Out:
# 3

# %% [markdown]
# ### Element zerowy to interesująca nas tabela

# %%
df_toronto[0]
# Out:
#                                                     0  \
# 0                                     M1ANot assigned
# 1                     M1BScarborough(Malvern / Rouge)
# 2   M1CScarborough(Rouge Hill / Port Union / Highl...
# 3   M1EScarborough(Guildwood / Morningside / West ...
# 4                              M1GScarborough(Woburn)
# 5                           M1HScarborough(Cedarbrae)
# 6                 M1JScarborough(Scarborough Village)
# 7   M1KScarborough(Kennedy Park / Ionview / East B...
# 8   M1LScarborough(Golden Mile / Clairlea / Oakridge)
# 9   M1MScarborough(Cliffside / Cliffcrest / Scarbo...
# 10       M1NScarborough(Birch Cliff / Cliffside West)
# 11  M1PScarborough(Dorset Park / Wexford Heights /...
# 12                 M1RScarborough(Wexford / Maryvale)
# 13                          M1SScarborough(Agincourt)
# 14  M1TScarborough(Clarks Corners / Tam O'Shanter ...
# 15  M1VScarborough(Milliken / Agincourt North / St...
# ...

# %%
df_toronto[0].shape
# Out:
# (20, 9)

# %%
df_toronto[0][0].shape
# Out:
# (20,)

# %%
df_toronto[0][0]
# Out:
# 0                                       M1ANot assigned
# 1                       M1BScarborough(Malvern / Rouge)
# 2     M1CScarborough(Rouge Hill / Port Union / Highl...
# 3     M1EScarborough(Guildwood / Morningside / West ...
# 4                                M1GScarborough(Woburn)
# 5                             M1HScarborough(Cedarbrae)
# 6                   M1JScarborough(Scarborough Village)
# 7     M1KScarborough(Kennedy Park / Ionview / East B...
# 8     M1LScarborough(Golden Mile / Clairlea / Oakridge)
# 9     M1MScarborough(Cliffside / Cliffcrest / Scarbo...
# 10         M1NScarborough(Birch Cliff / Cliffside West)
# 11    M1PScarborough(Dorset Park / Wexford Heights /...
# 12                   M1RScarborough(Wexford / Maryvale)
# 13                            M1SScarborough(Agincourt)
# 14    M1TScarborough(Clarks Corners / Tam O'Shanter ...
# 15    M1VScarborough(Milliken / Agincourt North / St...
# 16       M1WScarborough(Steeles West / L'Amoreaux West)
# ...

# %%
df_toronto[0][0][0]
# Out:
# 'M1ANot assigned'

# %%
df_toronto[0][4][17]
# Out:
# 'M5XDowntown Toronto(First Canadian Place / Underground city)'

# %% [markdown]
# ### Będziemy przekształcać tabelę o wymiarach 9x20 na tabelę o wymiarach 1x180

# %% [markdown]
# #### Tworzenie pustej tabeli pandas i przypisanie pierwszej kolumny z df_toronto

# %%
#df_onecolumn= pd.DataFrame()
#df_onecolumn=df_toronto[0][0]
df_onecolumn = pd.DataFrame(df_toronto[0][0])
df_onecolumn.columns =['One_column']

# %%
df_onecolumn
# Out:
#                                            One_column
# 0                                     M1ANot assigned
# 1                     M1BScarborough(Malvern / Rouge)
# 2   M1CScarborough(Rouge Hill / Port Union / Highl...
# 3   M1EScarborough(Guildwood / Morningside / West ...
# 4                              M1GScarborough(Woburn)
# 5                           M1HScarborough(Cedarbrae)
# 6                 M1JScarborough(Scarborough Village)
# 7   M1KScarborough(Kennedy Park / Ionview / East B...
# 8   M1LScarborough(Golden Mile / Clairlea / Oakridge)
# 9   M1MScarborough(Cliffside / Cliffcrest / Scarbo...
# 10       M1NScarborough(Birch Cliff / Cliffside West)
# 11  M1PScarborough(Dorset Park / Wexford Heights /...
# 12                 M1RScarborough(Wexford / Maryvale)
# 13                          M1SScarborough(Agincourt)
# 14  M1TScarborough(Clarks Corners / Tam O'Shanter ...
# 15  M1VScarborough(Milliken / Agincourt North / St...
# ...

# %% [markdown]
# #### test concat

# %%
df_test1 = pd.DataFrame([[1, 2], [3, 4]], columns=list('AB'))
df_test1
# Out:
#    A  B
# 0  1  2
# 1  3  4

# %%
df_test2 = pd.DataFrame([[5, 6], [7, 8]], columns=list('AB'))
df_test2
# Out:
#    A  B
# 0  5  6
# 1  7  8

# %%
pd.concat([df_test1, df_test2], ignore_index=True)
# Out:
#    A  B
# 0  1  2
# 1  3  4
# 2  5  6
# 3  7  8

# %% [markdown]
# #### Dodanie pozostałych kolumn z tabeli df_toronto do df_onecolumn

# %%
for i in range(1,9):
    dfx=pd.DataFrame(df_toronto[0][i])
    dfx.columns =['One_column']
    #dfx.reset_index(drop=True, inplace=True)
    df_onecolumn = pd.concat([df_onecolumn, dfx], ignore_index=True)

# %%
df_onecolumn.shape
# Out:
# (180, 1)

# %%
df_onecolumn.to_csv(r'D:\GitHub\Coursera_Capstone\Toronto.csv', header=None, index=None, sep=',', mode='a')
df_onecolumn
# Out:
#                                             One_column
# 0                                      M1ANot assigned
# 1                      M1BScarborough(Malvern / Rouge)
# 2    M1CScarborough(Rouge Hill / Port Union / Highl...
# 3    M1EScarborough(Guildwood / Morningside / West ...
# 4                               M1GScarborough(Woburn)
# ..                                                 ...
# 175  M9VEtobicoke(South Steeles / Silverstone / Hum...
# 176  M9WEtobicokeNorthwest(Clairville / Humberwood ...
# 177                                    M9XNot assigned
# 178                                    M9YNot assigned
# 179                                    M9ZNot assigned
#
# [180 rows x 1 columns]

# %% [markdown]
# We will create one column with Postal Codes and second with the rest of strings

# %%
#df_onecolumn.insert(1, "Postal Code")
df_onecolumn["Postal Code"] = np.nan
df_onecolumn["Delete"] = np.nan
df_onecolumn["Borough"] = np.nan
df_onecolumn["Neighborhood"] = np.nan

# %%
df_onecolumn
# Out:
#                                             One_column  Postal Code  Delete  \
# 0                                      M1ANot assigned          NaN     NaN
# 1                      M1BScarborough(Malvern / Rouge)          NaN     NaN
# 2    M1CScarborough(Rouge Hill / Port Union / Highl...          NaN     NaN
# 3    M1EScarborough(Guildwood / Morningside / West ...          NaN     NaN
# 4                               M1GScarborough(Woburn)          NaN     NaN
# ..                                                 ...          ...     ...
# 175  M9VEtobicoke(South Steeles / Silverstone / Hum...          NaN     NaN
# 176  M9WEtobicokeNorthwest(Clairville / Humberwood ...          NaN     NaN
# 177                                    M9XNot assigned          NaN     NaN
# 178                                    M9YNot assigned          NaN     NaN
# 179                                    M9ZNot assigned          NaN     NaN
#
#      Borough  Neighborhood
# 0        NaN           NaN
# ...

# %%
df_onecolumn
# Out:
#                                             One_column  Postal Code  Delete  \
# 0                                      M1ANot assigned          NaN     NaN
# 1                      M1BScarborough(Malvern / Rouge)          NaN     NaN
# 2    M1CScarborough(Rouge Hill / Port Union / Highl...          NaN     NaN
# 3    M1EScarborough(Guildwood / Morningside / West ...          NaN     NaN
# 4                               M1GScarborough(Woburn)          NaN     NaN
# ..                                                 ...          ...     ...
# 175  M9VEtobicoke(South Steeles / Silverstone / Hum...          NaN     NaN
# 176  M9WEtobicokeNorthwest(Clairville / Humberwood ...          NaN     NaN
# 177                                    M9XNot assigned          NaN     NaN
# 178                                    M9YNot assigned          NaN     NaN
# 179                                    M9ZNot assigned          NaN     NaN
#
#      Borough  Neighborhood
# 0        NaN           NaN
# ...

# %%
df_onecolumn = pd.DataFrame(df_toronto[0][0])
df_onecolumn.columns =['One_column']
for i in range(1,9):
    dfx=pd.DataFrame(df_toronto[0][i])
    dfx.columns =['One_column']
    #dfx.reset_index(drop=True, inplace=True)
    df_onecolumn = pd.concat([df_onecolumn, dfx], ignore_index=True)

df_onecolumn["Postal Code"] = np.nan
df_onecolumn["Delete"] = np.nan
df_onecolumn["Borough"] = np.nan
df_onecolumn["Neighborhood"] = np.nan
df_onecolumn.head()
# Out:
#                                           One_column  Postal Code  Delete  \
# 0                                    M1ANot assigned          NaN     NaN
# 1                    M1BScarborough(Malvern / Rouge)          NaN     NaN
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...          NaN     NaN
# 3  M1EScarborough(Guildwood / Morningside / West ...          NaN     NaN
# 4                             M1GScarborough(Woburn)          NaN     NaN
#
#    Borough  Neighborhood
# 0      NaN           NaN
# 1      NaN           NaN
# 2      NaN           NaN
# 3      NaN           NaN
# 4      NaN           NaN

# %%
#Fulfilling Postal Code column with 3 first characters from One_column
for i in range(180):
    postal_code=df_onecolumn.loc[i,'One_column']
    df_onecolumn.loc[i,"Postal Code"]=postal_code[:3]
    
#Fulfilling Delete column with 15 next chatacters from One_colum. 
#The column Delet will be used to delete all "Not assigned" codes. 
    delete_column=df_onecolumn.loc[i,'One_column']
    df_onecolumn.loc[i,"Delete"]=delete_column[3:15]

df_onecolumn = df_onecolumn[df_onecolumn['Delete'] != 'Not assigned']

df_onecolumn=df_onecolumn.reset_index()
df_onecolumn = df_onecolumn.drop(['index'], axis=1)

df_onecolumn
# Out:
#                                             One_column Postal Code  \
# 0                      M1BScarborough(Malvern / Rouge)         M1B
# 1    M1CScarborough(Rouge Hill / Port Union / Highl...         M1C
# 2    M1EScarborough(Guildwood / Morningside / West ...         M1E
# 3                               M1GScarborough(Woburn)         M1G
# 4                            M1HScarborough(Cedarbrae)         M1H
# ..                                                 ...         ...
# 98                                     M9NYork(Weston)         M9N
# 99                             M9PEtobicoke(Westmount)         M9P
# 100  M9REtobicoke(Kingsview Village / St. Phillips ...         M9R
# 101  M9VEtobicoke(South Steeles / Silverstone / Hum...         M9V
# 102  M9WEtobicokeNorthwest(Clairville / Humberwood ...         M9W
#
#            Delete  Borough  Neighborhood
# 0    Scarborough(      NaN           NaN
# 1    Scarborough(      NaN           NaN
# ...

# %%
for i in range(df_onecolumn.shape[0]):
    #print(i)
    a=df_onecolumn.loc[i,'One_column']
    #print(a)
    a=a[3:]
    #print(a)
    b=a.split("(")[1]
    #print(b)
    a=a.split("(")[0]
    #print(a)
    df_onecolumn.loc[i,"Borough"]=a
    df_onecolumn.loc[i,"Neighborhood"]=b

df_onecolumn = df_onecolumn.drop(['Delete'], axis=1)

for i in range(df_onecolumn.shape[0]):
    a=df_onecolumn.loc[i,'Neighborhood']
    a=a.split(")")[0]
    a=a.replace(" / ",", ")
    
    df_onecolumn.loc[i,"Neighborhood"]=a

# %%
df_onecolumn.to_csv(r'D:\GitHub\Coursera_Capstone\Final_data.csv', header=None, index=None, sep=';', mode='a')

# %%
df_onecolumn.loc[[54]]
# Out:
#                                        One_column Postal Code  \
# 54  M5BDowntown Toronto(Garden District, Ryerson)         M5B
#
#              Borough              Neighborhood
# 54  Downtown Toronto  Garden District, Ryerson

# %%
df_copy=df_onecolumn

# %%
df_onecolumn=df_copy

# %%
for i in range(df_onecolumn.shape[0]):
    a=df_onecolumn.loc[i,'Neighborhood']
    a=a.split(")")[0]
    a=a.replace(" / ",", ")
    #a=a.replace('_,_',', ')
    #a=a.replace('_',", ")
    df_onecolumn.loc[i,"Neighborhood"]=a

# %%
df_onecolumn
# Out:
#                                             One_column Postal Code  \
# 0                      M1BScarborough(Malvern / Rouge)         M1B
# 1    M1CScarborough(Rouge Hill / Port Union / Highl...         M1C
# 2    M1EScarborough(Guildwood / Morningside / West ...         M1E
# 3                               M1GScarborough(Woburn)         M1G
# 4                            M1HScarborough(Cedarbrae)         M1H
# ..                                                 ...         ...
# 98                                     M9NYork(Weston)         M9N
# 99                             M9PEtobicoke(Westmount)         M9P
# 100  M9REtobicoke(Kingsview Village / St. Phillips ...         M9R
# 101  M9VEtobicoke(South Steeles / Silverstone / Hum...         M9V
# 102  M9WEtobicokeNorthwest(Clairville / Humberwood ...         M9W
#
#                 Borough                                       Neighborhood
# 0           Scarborough                                     Malvern, Rouge
# ...

# %%
a=df_onecolumn.loc[1,'One_column']
print(a)
a=a[3:]
print(a)
b=a.split("(")[1]
a=a.split("(")[0]
print(a)
print(b)
# Out:
# M1BScarborough(Malvern / Rouge)
# Scarborough(Malvern / Rouge)
# Scarborough
# Malvern / Rouge)

# %%
df_onecolumn.shape
# Out:
# (103, 4)

# %%
for i in range(2):
    a=df_onecolumn.loc[i,'One_column']
    print(a)
    a=a[3:]
    print(a)
    b=a.split("(")[1]
    a=a.split("(")[0]
    print(a)
    print(b)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-377-c07a9edeabb0> in <module>
#       1 for i in range(2):
# ...

# %%
df_onecolumn.loc[1]
# Out:
# One_column      M1BScarborough(Malvern / Rouge)
# Postal Code                                 NaN
# Delete                                      NaN
# Borough                                     NaN
# Neighborhood                                NaN
# Name: 1, dtype: object

# %%
df_onecolumn.loc[[2]]
# Out:
#                                           One_column Postal Code  Delete  \
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...        xxxx     NaN
#
#    Borough  Neighborhood
# 2      NaN           NaN

# %%
df_onecolumn.loc[2,"Postal Code"]
# Out:
# 'xxxx'

# %%
df_onecolumn.loc[2,"Postal Code"]='xxxx'

# %%
a=df_onecolumn.loc[2,'One_column']
df_onecolumn.loc[2,"Postal Code"]=a[:3]
df_onecolumn.loc[[2]]
# Out:
#                                           One_column Postal Code  Delete  \
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...         M1C     NaN
#
#    Borough  Neighborhood
# 2      NaN           NaN

# %%
a = ("a", "b", "c", "d", "e", "f", "g", "h")
x = slice(3, 5)
print(a[x])
# Out:
# ('d', 'e')

# %%
df_onecolumn['Postal Code']=df_onecolumn['One_column'].str.slice(stop=3)
df_onecolumn['Delete']=df_onecolumn['One_column'].str.slice(start=3, stop=15)
#df_onecolumn['Borough']=df_onecolumn['One_column'].str.slice(start=3, stop=15)
df_onecolumn['Borough']=df_onecolumn['One_column'].str.split(' \(', expand=True)

# %%
df_onecolumn
# Out:
#                                             One_column Postal Code  \
# 0                                      M1ANot assigned         M1A
# 1                      M1BScarborough(Malvern / Rouge)         M1B
# 2    M1CScarborough(Rouge Hill / Port Union / Highl...         M1C
# 3    M1EScarborough(Guildwood / Morningside / West ...         M1E
# 4                               M1GScarborough(Woburn)         M1G
# ..                                                 ...         ...
# 175  M9VEtobicoke(South Steeles / Silverstone / Hum...         M9V
# 176  M9WEtobicokeNorthwest(Clairville / Humberwood ...         M9W
# 177                                    M9XNot assigned         M9X
# 178                                    M9YNot assigned         M9Y
# 179                                    M9ZNot assigned         M9Z
#
#            Delete                                            Borough  \
# 0    Not assigned                                    M1ANot assigned
# ...

# %%
df_onecolumn = df_onecolumn[df_onecolumn['Delete'] != 'Not assigned']
df_onecolumn
# Out:
#                                             One_column Postal Code  \
# 1                      M1BScarborough(Malvern / Rouge)         M1B
# 2    M1CScarborough(Rouge Hill / Port Union / Highl...         M1C
# 3    M1EScarborough(Guildwood / Morningside / West ...         M1E
# 4                               M1GScarborough(Woburn)         M1G
# 5                            M1HScarborough(Cedarbrae)         M1H
# ..                                                 ...         ...
# 170                                    M9NYork(Weston)         M9N
# 171                            M9PEtobicoke(Westmount)         M9P
# 172  M9REtobicoke(Kingsview Village / St. Phillips ...         M9R
# 175  M9VEtobicoke(South Steeles / Silverstone / Hum...         M9V
# 176  M9WEtobicokeNorthwest(Clairville / Humberwood ...         M9W
#
#            Delete                                            Borough  \
# 1    Scarborough(                    M1BScarborough(Malvern / Rouge)
# ...

# %%
df_onecolumn.to_csv(r'D:\GitHub\Coursera_Capstone\onecolumn.txt', header=None, index=None, sep=',', mode='a')

# %%
df_onecolumn['Delete']
# Out:
# 1      Scarborough(
# 2      Scarborough(
# 3      Scarborough(
# 4      Scarborough(
# 5      Scarborough(
#            ...
# 170    York(Weston)
# 171    Etobicoke(We
# 172    Etobicoke(Ki
# 175    Etobicoke(So
# 176    EtobicokeNor
# Name: Delete, Length: 103, dtype: object

# %%
#df_onecolumn['Borough'] = df_onecolumn.Delete.str.split(' \(', expand=True)
#df_onecolumn['Borough'] = df_onecolumn['Delete'].str.split(' \(', expand=True)
#df_onecolumn['Borough'] = df_onecolumn['One_column'].str.slice(start=3, stop=15)
df_onecolumn['Borough']=df_onecolumn['One_column'].str.slice(start=3, stop=15)
# Out:
# <ipython-input-65-9a322fb033db>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_onecolumn['Borough']=df_onecolumn['One_column'].str.slice(start=3, stop=15)

# %% [markdown]
# ### slice upon character

# %%
#slice upon character

df = pd.DataFrame({'Name': ['Braund, Mr. Owen Harris',
                           'Cummings, Mrs. John Bradley (Florence Briggs)',
                           'Heikkinen, Miss. Laina',
                           'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
                           'Allen, Mr. William Henry']})

# %%
df
# Out:
#                                             Name
# 0                        Braund, Mr. Owen Harris
# 1  Cummings, Mrs. John Bradley (Florence Briggs)
# 2                         Heikkinen, Miss. Laina
# 3   Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                       Allen, Mr. William Henry

# %% [markdown]
# # To mi pomoże z kolumną Borough

# %%
df['Name'] = df.Name.str.split(' \(', expand=True)[0]

# %%
df
# Out:
#                            Name
# 0       Braund, Mr. Owen Harris
# 1   Cummings, Mrs. John Bradley
# 2        Heikkinen, Miss. Laina
# 3  Futrelle, Mrs. Jacques Heath
# 4      Allen, Mr. William Henry

# %% [markdown]
# #### Export do pliku

# %%
df_onecolumn.to_csv(r'D:\GitHub\Coursera_Capstone\onecolumn.txt', header=None, index=None, sep=',', mode='a')

# %%
df_onecolumn['PostalCode']=df_onecolumn.str.slice(stop=3)

# %%
df_onecolumn.shape
# Out:
# (181,)

# %%
df_onecolumn
# Out:
# 0                                M9AEtobicoke(Islington Avenue)
# 1             M9BEtobicoke(West Deane Park / Princess Garden...
# 2             M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3                                               M9ENot assigned
# 4                                               M9GNot assigned
#                                     ...
# 176              M1WScarborough(Steeles West / L'Amoreaux West)
# 177                                 M1XScarborough(Upper Rouge)
# 178                                             M1YNot assigned
# 179                                             M1ZNot assigned
# PostalCode    0      M9A
# 1      M9B
# 2      M9C
# 3      M9E
# 4 ...
# Length: 181, dtype: object

# %%
for col in df_onecolumn:
    print(col)
# Out:
# M9AEtobicoke(Islington Avenue)
# M9BEtobicoke(West Deane Park / Princess Gardens / Martin Grove / Islington / Cloverdale)
# M9CEtobicoke(Eringate / Bloordale Gardens / Old Burnhamthorpe / Markland Wood)
# M9ENot assigned
# M9GNot assigned
# M9HNot assigned
# M9JNot assigned
# M9KNot assigned
# M9LNorth York(Humber Summit)
# M9MNorth York(Humberlea / Emery)
# M9NYork(Weston)
# M9PEtobicoke(Westmount)
# M9REtobicoke(Kingsview Village / St. Phillips / Martin Grove Gardens / Richview Gardens)
# M9SNot assigned
# M9TNot assigned
# M9VEtobicoke(South Steeles / Silverstone / Humbergate / Jamestown / Mount Olive / Beaumond Heights / Thistletown / Albion Gardens)
# M9WEtobicokeNorthwest(Clairville / Humberwood / Woodbine Downs / West Humber / Kipling Heights / Rexdale / Elms / Tandridge / Old Rexdale)
# M9XNot assigned
# M9YNot assigned
# M9ZNot assigned
# M8ANot assigned
# M8BNot assigned
# M8CNot assigned
# M8ENot assigned
# M8GNot assigned
# M8HNot assigned
# M8JNot assigned
# ...

# %%
df_onecolumn.pivot(columns='var',values='val')
